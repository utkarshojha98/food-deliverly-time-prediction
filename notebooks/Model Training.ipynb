# %%
import pandas as pd
# Out:
# Running cells with 'd:\Documents\dilevery time\env\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p d:\Documents\dilevery time\env ipykernel --update-deps --force-reinstall'

# %% [markdown]
# ## Model Training

# %%
pip install pandas

# %%
df = pd.read_csv('finalTrain.csv')
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
df['Date']=df['Order_Date'].apply(lambda x:x.split('-'))
df
# Out:
#            ID Delivery_person_ID  Delivery_person_Age
# 0      0xcdcd      DEHRES17DEL01                 36.0  \
# 1      0xd987      KOCRES16DEL01                 21.0
# 2      0x2784     PUNERES13DEL03                 23.0
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 4      0xdb64      KNPRES14DEL02                 24.0
# ...       ...                ...                  ...
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 0                          4.2            30.327968             78.046106  \
# 1                          4.7            10.003064             76.307589
# 2                          4.7            18.562450             73.916619
# ...

# %%
df['Date']=df['Order_Date'].apply(lambda x:x.split('-'))

# %%
df['day']=df['Order_Date'].str.split('-').str[0]
df['month']=df['Order_Date'].str.split('-').str[1]
df['year']=df['Order_Date'].str.split('-').str[2]

# %%
df['hour_Order_picked']=df['Time_Orderd'].str.split(':').str[0]
df['min_Order_picked']=df['Time_Orderd'].str.split(':').str[1]

# %%
df['order_hour']=df['Time_Orderd'].str.split(':').str[0]
df['order_min']=df['Time_Orderd'].str.split(':').str[1]

# %%
pd.Categorical(df)
# Out:
# ['ID', 'Delivery_person_ID', 'Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', ..., 'year', 'hour_Order_picked', 'min_Order_picked', 'order_hour', 'order_min']
# Length: 28
# Categories (28, object): ['City', 'Date', 'Delivery_location_latitude', 'Delivery_location_longitude', ..., 'multiple_deliveries', 'order_hour', 'order_min', 'year']

# %%
df=df.drop(labels=['ID','Delivery_person_ID','Date','Order_Date','Time_Orderd','Time_Order_picked'],axis=1)

# %%
df.hour_Order_picked=df['hour_Order_picked'].astype(float)
df.day=df['day'].astype(float)
df.month=df[ 'month'].astype(float)
df.year=df['year'].astype(float)
df.min_Order_picked=df['min_Order_picked'].astype(float)
df.order_hour=df['order_hour'].astype(float)
df.order_min=df['order_min'].astype(float)

# %%
## Independent and dependent features
X = df.drop(labels=['Time_taken (min)'],axis=1)
Y = df[['Time_taken (min)']]

# %%
Y
# Out:
#        Time_taken (min)
# 0                    46
# 1                    23
# 2                    21
# 3                    20
# 4                    41
# ...                 ...
# 45579                32
# 45580                36
# 45581                16
# 45582                26
# 45583                36
#
# [45584 rows x 1 columns]

# %%
# Define which columns should be ordinal-encoded and which should be scaled
categorical_cols = X.select_dtypes(include='object').columns
numerical_cols = X.select_dtypes(exclude='object').columns

# %%
numerical_cols
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Vehicle_condition',
#        'multiple_deliveries', 'day', 'month', 'year', 'hour_Order_picked',
#        'min_Order_picked', 'order_hour', 'order_min'],
#       dtype='object')

# %%
pd.Categorical(df)
# Out:
# ['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', ..., 'year', 'hour_Order_picked', 'min_Order_picked', 'order_hour', 'order_min']
# Length: 22
# Categories (22, object): ['City', 'Delivery_location_latitude', 'Delivery_location_longitude', 'Delivery_person_Age', ..., 'multiple_deliveries', 'order_hour', 'order_min', 'year']

# %%
# Define the custom ranking for each ordinal variable
Weather_conditions=['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny']
Road_traffic_density=['Jam', 'High', 'Medium', 'Low', 'nan']
Type_of_order= ['Snack', 'Meal', 'Drinks', 'Buffet']
Type_of_vehicle=['motorcycle', 'scooter', 'electric_scooter', 'bicycle']
Festival=['No', 'Yes', 'nan']
City= ['Metropolitian', 'Urban', 'Semi-Urban', 'nan']

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
df.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude
# 0                 36.0                      4.2            30.327968  \
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude
# 0             78.046106                   30.397968  \
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude Weather_conditions Road_traffic_density
# 0                    78.116106                Fog                  Jam  \
# 1                    76.347589             Stormy                 High
# ...

# %%
## Numerical Pipeline
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())

    ]

)

# Categorigal Pipeline
cat_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('ordinalencoder',OrdinalEncoder(categories=[Weather_conditions,Road_traffic_density,Type_of_order,Type_of_vehicle,Festival,City
])),
    ('scaler',StandardScaler())
    ]

)

preprocessor=ColumnTransformer([
('num_pipeline',num_pipeline,numerical_cols),
('cat_pipeline',cat_pipeline,categorical_cols)
])

# %%
## Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.30,random_state=30)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train.head()
# Out:
#    num_pipeline__Delivery_person_Age  num_pipeline__Delivery_person_Ratings
# 0                           1.124025                              -1.623440  \
# 1                          -0.106505                              -3.143059
# 2                           0.245075                               0.504025
# 3                           0.596655                              -1.319517
# 4                           0.772445                              -1.623440
#
#    num_pipeline__Restaurant_latitude  num_pipeline__Restaurant_longitude
# 0                           0.647373                            0.131167  \
# 1                           0.647397                            0.131248
# 2                           1.156141                            0.443938
# 3                          -0.226656                            0.165206
# 4                           0.258322                            0.116402
#
#    num_pipeline__Delivery_location_latitude
# ...

# %%
## Model Training

from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([[ 2.26757677e+00, -2.32676262e+00,  1.06514944e-02,
#         -4.65060038e-01,  4.30442327e-02,  4.09978402e-01,
#         -1.78659822e+00,  2.06165067e+00,  7.28281575e-02,
#          1.53930864e-03,  8.77120311e+10,  9.29609585e+10,
#          7.38892950e+12, -9.29609585e+10, -7.38892950e+12,
#         -1.15974537e+00, -3.15372419e+00, -4.57151320e-02,
#         -1.80304331e-02,  1.60346602e+00, -7.49093903e-01]])

# %%
regression.intercept_
# Out:
# array([26.31769462])

# %%
import numpy as np
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
## Train multiple models

models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet()
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Predictions
    y_pred=model.predict(X_test)

    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("RMSE:",rmse)
    print("MAE:",mae)
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 6.666513961189576
# MAE: 5.260705709723835
# R2 score 48.61847322862097
# ...
#
#
# Lasso
# Model Training Performance
# RMSE: 7.081947624124816
# MAE: 5.638425369306291
# R2 score 42.015109674383055
# ...
#
#
# Ridge
# Model Training Performance
# RMSE: 6.666407603921795
# MAE: 5.260648819637144
# R2 score 48.62011269273702
# ...
#
#
# Elasticnet
# Model Training Performance
# RMSE: 7.131356305221122
# MAE: 5.69306444243002
# R2 score 41.203199987603526
# ...

# %%
model_list
# Out:
# ['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet']
